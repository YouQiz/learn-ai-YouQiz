# %% [markdown]
# # crazy-day
# > 疯狂的一天
# > 练习 Markdown

# %% [markdown]
# ## 上午
# 7 点起床，突发奇想，决定出门

# %% [markdown]
# ### 早餐
# 食物如下：
#
# | 名称 | 数量 | 备注     |
# |------|------|----------|
# | 牛奶 | 1 盒 | 常温     |
# | 面包 | 2 片 | 全麦面包 |
# | 鸡蛋 | 1 个 | 茶叶蛋   |
#
# 吃完早餐，打开高德地图，寻找最近的网吧···

# %% [markdown]
# ### 网吧
# 当然是来网吧写个酣畅淋漓的 python 小脚本

# %%
# 计算出门游玩时长
start_hour = 7
end_hour = 20
total_hour = end_hour - start_hour
print(f"本次出门一共 {total_hour} 小时")
# Out:
# 本次出门一共 13 小时

# %%
![](https://mmbiz.qpic.cn/mmbiz_jpg/FrlMmzeTicAAzpTeK1vpQlF69gNNF1M3tqlkFrbichScgiamQfrmsfdeUogMbpBL9B4mNfTPjoS2gH67ibiaQKfBYwg/640?wx_fmt=jpeg&from=appmsg&tp=webp&wxfrom=5&wx_lazy=1#imgIndex=5)
# Out:
# '[]' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# 'from' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# 'tp' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# 'wxfrom' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# 'wx_lazy' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
